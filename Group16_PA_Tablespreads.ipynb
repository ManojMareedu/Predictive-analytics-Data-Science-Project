# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os 

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/Datasets/')

# %% [markdown]
# # Reading the Data which is in .xlsx format.

# %%
df2018 = pd.read_excel("/content/drive/MyDrive/Datasets/IRI_POS_Tablespreads_2018.xlsx")

# %%
df2019 = pd.read_excel("/content/drive/MyDrive/Datasets/IRI_POS_Tablespreads_2019.xlsx")

# %%
df2020 = pd.read_excel("/content/drive/MyDrive/Datasets/IRI_POS_Tablespreads_2020.xlsx")

# %%
df2021 = pd.read_excel("/content/drive/MyDrive/Datasets/IRI_POS_Tablespreads_2021.xlsx")

# %%
df2022 = pd.read_excel("/content/drive/MyDrive/Datasets/IRI_POS_Tablespreads_2022.xlsx")

# %%
df2022 = df2022.rename(columns={"Product": "Product Description"})

# %% [markdown]
# # Removing the Duplicates

# %%
df2018.drop_duplicates()
# Out:
#                                         Geography                  Time  \
# 0                  Total US - Multi Outlet + Conv  Week Ending 01-14-18
# 1                  Total US - Multi Outlet + Conv  Week Ending 01-14-18
# 2                  Total US - Multi Outlet + Conv  Week Ending 01-14-18
# 3                  Total US - Multi Outlet + Conv  Week Ending 01-14-18
# 4                  Total US - Multi Outlet + Conv  Week Ending 01-14-18
# ...                                           ...                   ...
# 270647  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-06-19
# 270648  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-06-19
# 270649  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-06-19
# 270650  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-06-19
# 270651  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-06-19
#
#                                       Product Description  UPC 13 digit  \
# 0       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...   29000008222
# 1       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...   29000008563
# 2       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX STICK...   70272006101
# 3       BLUE BONNET RFG VEGETABLE OIL SPREAD INDIVDL W...   29000008252
# 4       BLUE BONNET RFG VEGETABLE OIL SPREAD PLASTIC T...   27000009002
# ...                                                   ...           ...
# 270647  VITAL FARMS RFG BUTTER INDIVDL WRAP IN BOX STI...  861745000081
# 270648  WAYFARE RFG VEGETABLE OIL SPREAD PLASTIC TUB S...  845681000651
# 270649  COUNTRY CREAM RFG BUTTER BOX QUARTER 16 OZ - 0...   54231100073
# 270650  TABLE MAID RFG VEGETABLE OIL SPREAD BOX QUARTE...   26700161221
# 270651  TABLE MAID RFG VEGETABLE OIL SPREAD PLASTIC TU...   26700159071
#
#         Dollar Sales No Merch  Dollar Sales Any Merch  Unit Sales No Merch  \
# 0                1.255982e+06           168416.455688         1.241794e+06
# 1                1.507009e+05            15573.717697         1.525283e+05
# 2                1.740030e+04              644.397026         1.736027e+04
# 3                2.876466e+05            14088.692349         1.527090e+05
# 4                3.601990e+05            52619.025497         2.281632e+05
# ...                       ...                     ...                  ...
# 270647           1.888303e+03                     NaN         4.533396e+02
# 270648           4.354680e+02                     NaN         1.252345e+02
# 270649           4.997956e+01                     NaN         1.001594e+01
# 270650           5.160000e+02                     NaN         4.000000e+02
# 270651           8.608000e+02                     NaN         3.200000e+02
#
#         Unit Sales Any Merch  Volume Sales No Merch  Volume Sales Any Merch  \
# 0              182993.872299           1.241794e+06           182993.872299
# 1               17263.338023           1.525283e+05            17263.338023
# 2                 717.499949           1.736027e+04              717.499949
# 3                8311.540143           3.054180e+05            16623.080285
# 4               37591.803778           2.139030e+05            35242.316041
# ...                      ...                    ...                     ...
# 270647                   NaN           2.266698e+02                     NaN
# 270648                   NaN           1.095802e+02                     NaN
# 270649                   NaN           1.001594e+01                     NaN
# 270650                   NaN           4.000000e+02                     NaN
# 270651                   NaN           6.000000e+02                     NaN
#
#         ...  Price per Volume No Merch  Price per Volume Any Merch  \
# 0       ...                   1.011426                    0.920339
# 1       ...                   0.988020                    0.902127
# 2       ...                   1.002306                    0.898114
# 3       ...                   0.941813                    0.847538
# 4       ...                   1.683936                    1.493064
# ...     ...                        ...                         ...
# 270647  ...                   8.330632                         NaN
# 270648  ...                   3.973968                         NaN
# 270649  ...                   4.990000                         NaN
# 270650  ...                   1.290000                         NaN
# 270651  ...                   1.434667                         NaN
#
#         ACV Weighted Distribution No Merch  \
# 0                                64.382639
# 1                                27.394093
# 2                                 6.917577
# 3                                18.721969
# 4                                45.916324
# ...                                    ...
# 270647                            3.258901
# 270648                            0.703434
# 270649                            0.003586
# 270650                            0.118876
# 270651                            0.118876
#
#         ACV Weighted Distribution Any Merch  Base Unit Sales  \
# 0                                  5.720845     1.344519e+06
# 1                                  1.846392     1.626122e+05
# 2                                  0.133754     1.776079e+04
# 3                                  1.431474     1.597783e+05
# 4                                  4.987405     2.484898e+05
# ...                                     ...              ...
# 270647                                  NaN     4.533396e+02
# 270648                                  NaN     1.252345e+02
# 270649                                  NaN     1.001594e+01
# 270650                                  NaN     4.000000e+02
# 270651                                  NaN     3.200000e+02
#
#         Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0            1.344519e+06       1.363962e+06       80268.496957
# 1            1.626122e+05       1.608675e+05        7179.481780
# 2            1.776079e+04       1.778694e+04         316.976631
# 3            3.195565e+05       3.002505e+05        1242.285033
# 4            2.329592e+05       3.950170e+05       17265.155511
# ...                   ...                ...                ...
# 270647       2.266698e+02       1.888303e+03                NaN
# 270648       1.095802e+02       4.354680e+02                NaN
# 270649       1.001594e+01       4.997956e+01                NaN
# 270650       4.000000e+02       5.160000e+02                NaN
# 270651       6.000000e+02       8.608000e+02                NaN
#
#         Incremental Volume  Incremental Dollars
# 0             80268.496987         60436.436932
# 1              7179.481790          5407.131816
# 2               316.976622           257.755413
# 3              2484.570073          1484.776013
# 4             16186.083274         17801.030415
# ...                    ...                  ...
# 270647                 NaN                  NaN
# 270648                 NaN                  NaN
# 270649                 NaN                  NaN
# 270650                 NaN                  NaN
# 270651                 NaN                  NaN
#
# [270652 rows x 24 columns]

# %%
df2020.drop_duplicates()
# Out:
#                                         Geography                  Time  \
# 0                  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 1                  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 2                  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 3                  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# 4                  Total US - Multi Outlet + Conv  Week Ending 01-12-20
# ...                                           ...                   ...
# 268337  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 268338  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 268339  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 268340  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-03-21
# 268341  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-03-21
#
#                                       Product Description   UPC 13 digit  \
# 0       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008222
# 1       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008563
# 2       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...  2700710746763
# 3       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX STICK...    70272006101
# 4       BLUE BONNET RFG VEGETABLE OIL SPREAD INDIVDL W...    29000008252
# ...                                                   ...            ...
# 268337  VERMONT RFG BUTTER INDIVDL WRAP IN BOX STICK 8...    11826750111
# 268338  VERMONT RFG BUTTER PAPER WRAPPED BLOCK 4 OZ - ...    11826801071
# 268339  VITAL FARMS RFG BUTTER INDIVDL WRAP IN BOX STI...   861745000071
# 268340  VITAL FARMS RFG BUTTER INDIVDL WRAP IN BOX STI...   861745000081
# 268341  WAYFARE RFG BUTTER PLASTIC TUB WHIPPED 12 OZ -...   845681001511
#
#         Dollar Sales No Merch  Dollar Sales Any Merch  Unit Sales No Merch  \
# 0                1.181608e+06           145701.232504         1.152310e+06
# 1                5.263167e+04             7267.738055         5.055877e+04
# 2                1.790000e+00                     NaN         2.000000e+00
# 3                7.168975e+03             1805.701378         7.023087e+03
# 4                8.555770e+04             2218.675016         4.328042e+04
# ...                       ...                     ...                  ...
# 268337           1.665789e+03              509.300000         4.763364e+02
# 268338           2.730000e+00                     NaN         1.000000e+00
# 268339           1.971106e+04            20143.167715         4.659314e+03
# 268340           7.503202e+03            14341.622475         1.813787e+03
# 268341                    NaN               97.366922                  NaN
#
#         Unit Sales Any Merch  Volume Sales No Merch  Volume Sales Any Merch  \
# 0              166220.062140           1.152310e+06           166220.062140
# 1                8336.771839           5.055877e+04             8336.771839
# 2                        NaN           2.000000e+00                     NaN
# 3                2014.694905           7.023087e+03             2014.694905
# 4                1119.400723           8.656084e+04             2238.801445
# ...                      ...                    ...                     ...
# 268337            203.000000           2.381682e+02              101.500000
# 268338                   NaN           2.500000e-01                     NaN
# 268339           5413.789442           2.329657e+03             2706.894721
# 268340           3856.920912           9.068935e+02             1928.460456
# 268341             39.103181                    NaN               29.327386
#
#         ...  Price per Volume No Merch  Price per Volume Any Merch  \
# 0       ...                   1.025426                    0.876556
# 1       ...                   1.041000                    0.871769
# 2       ...                   0.895000                         NaN
# 3       ...                   1.020773                    0.896265
# 4       ...                   0.988411                    0.991010
# ...     ...                        ...                         ...
# 268337  ...                   6.994169                    5.017734
# 268338  ...                  10.920000                         NaN
# 268339  ...                   8.460930                    7.441430
# 268340  ...                   8.273520                    7.436825
# 268341  ...                        NaN                    3.320000
#
#         ACV Weighted Distribution No Merch  \
# 0                                47.863621
# 1                                 8.906162
# 2                                 0.004184
# 3                                 2.486694
# 4                                 4.195265
# ...                                    ...
# 268337                            2.847623
# 268338                            0.015505
# 268339                           19.111927
# 268340                            8.566336
# 268341                                 NaN
#
#         ACV Weighted Distribution Any Merch  Base Unit Sales  \
# 0                                  5.403421     1.257422e+06
# 1                                  0.494859     5.459605e+04
# 2                                       NaN     2.000000e+00
# 3                                  0.130828     7.767225e+03
# 4                                  0.017958     4.368885e+04
# ...                                     ...              ...
# 268337                             0.545380     5.584464e+02
# 268338                                  NaN     1.000000e+00
# 268339                            26.233234     8.792914e+03
# 268340                            22.201297     5.033343e+03
# 268341                             0.072915     7.708914e+00
#
#         Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0            1.257422e+06       1.286905e+06       61108.026615
# 1            5.459605e+04       5.716338e+04        4299.496015
# 2            2.000000e+00       1.790000e+00                NaN
# 3            7.767225e+03       8.041101e+03        1270.557377
# 4            8.737770e+04       8.645315e+04         710.971111
# ...                   ...                ...                ...
# 268337       2.792232e+02       1.900203e+03         120.890001
# 268338       2.500000e-01       2.730000e+00                NaN
# 268339       4.396457e+03       3.628358e+04        1280.188911
# 268340       2.516672e+03       2.032679e+04         637.364431
# 268341       5.781685e+00       3.382873e+01          31.394268
#
#         Incremental Volume  Incremental Dollars
# 0             61108.026191         40404.031725
# 1              4299.495996          2736.029155
# 2                      NaN                  NaN
# 3              1270.557365           933.575722
# 4              1421.942149          1323.221067
# ...                    ...                  ...
# 268337           60.445000           274.885597
# 268338                 NaN                  NaN
# 268339          640.094455          3570.648637
# 268340          318.682216          1518.035595
# 268341           23.545701            63.538196
#
# [268342 rows x 24 columns]

# %%
df2022.drop_duplicates()
# Out:
#                                         Geography                  Time  \
# 0                  Total US - Multi Outlet + Conv  Week Ending 04-10-22
# 1                  Total US - Multi Outlet + Conv  Week Ending 04-10-22
# 2                  Total US - Multi Outlet + Conv  Week Ending 04-10-22
# 3                  Total US - Multi Outlet + Conv  Week Ending 04-10-22
# 4                  Total US - Multi Outlet + Conv  Week Ending 04-10-22
# ...                                           ...                   ...
# 247205  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247206  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247207  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247208  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247209  West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
#
#                                       Product Description   UPC 13 digit  \
# 0       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008222
# 1       BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008563
# 2       BLUE BONNET RFG VEGETABLE OIL SPREAD INDIVDL W...    29000008252
# 3       BLUE BONNET RFG VEGETABLE OIL SPREAD PLASTIC T...    27000009002
# 4       BLUE BONNET RFG VEGETABLE OIL SPREAD PLASTIC T...    27000009301
# ...                                                   ...            ...
# 247205  WAYFARE RFG BUTTER PLASTIC TUB WHIPPED 12 OZ -...   845681001511
# 247206  COUNTRY CREAM RFG BUTTER PAPER WRAPPED BLOCK 1...    54231100033
# 247207  WESTGOLD RFG BUTTER BOX QUARTER 8 OZ - 9421016...  9421016151221
# 247208  WESTGOLD RFG BUTTER FOIL WRAPPED BLOCK 8 OZ - ...  9421016151231
# 247209  WILDBRINE RFG BUTTER SUBSTITUTE PLASTIC TUB SP...   857859007121
#
#         Dollar Sales No Merch  Dollar Sales Any Merch  Unit Sales No Merch  \
# 0                1.088910e+06           146880.565443        937262.522463
# 1                4.490108e+04            10248.728577         38808.407025
# 2                5.817064e+04             3101.773105         23261.694744
# 3                2.324966e+05            12934.069323        117940.681316
# 4                3.622984e+04              282.533668         18824.140361
# ...                       ...                     ...                  ...
# 247205                    NaN                2.723205                  NaN
# 247206           1.059518e+02              291.051912            15.604098
# 247207           2.527800e+02             8660.720000            66.000000
# 247208           2.273200e+02             5986.640000            58.000000
# 247209           4.657836e+02                     NaN            70.862558
#
#         Unit Sales Any Merch  Volume Sales No Merch  Volume Sales Any Merch  \
# 0              131813.603009          937262.522463           131813.603009
# 1                8936.592409           38808.407025             8936.592409
# 2                1555.268466           46523.389488             3110.536932
# 3                7060.648479          110569.388734             6619.357949
# 4                 152.200069           17647.631589              142.687565
# ...                      ...                    ...                     ...
# 247205              1.055506                    NaN                0.791629
# 247206             64.249870              15.604098               64.249870
# 247207           2305.000000              33.000000             1152.500000
# 247208           1593.000000              29.000000              796.500000
# 247209                   NaN              53.146919                     NaN
#
#         ...  Price per Volume No Merch  Price per Volume Any Merch  \
# 0       ...                   1.161799                    1.114305
# 1       ...                   1.156994                    1.146827
# 2       ...                   1.250353                    0.997183
# 3       ...                   2.102721                    1.953976
# 4       ...                   2.052957                    1.980086
# ...     ...                        ...                         ...
# 247205  ...                        NaN                    3.440000
# 247206  ...                   6.790000                    4.530000
# 247207  ...                   7.660000                    7.514725
# 247208  ...                   7.838621                    7.516183
# 247209  ...                   8.764075                         NaN
#
#         ACV Weighted Distribution No Merch  \
# 0                                43.706176
# 1                                 5.492362
# 2                                 2.050543
# 3                                26.319175
# 4                                 6.243850
# ...                                    ...
# 247205                                 NaN
# 247206                            0.107566
# 247207                            0.511593
# 247208                            0.533303
# 247209                            0.978980
#
#         ACV Weighted Distribution Any Merch  Base Unit Sales  \
# 0                                  4.402609     1.009909e+06
# 1                                  1.014832     4.370129e+04
# 2                                  0.068772     2.419815e+04
# 3                                  1.711830     1.223989e+05
# 4                                  0.063546     1.896075e+04
# ...                                     ...              ...
# 247205                             0.050271     1.055506e+00
# 247206                             0.169880     3.600343e+01
# 247207                            11.384921     1.130330e+03
# 247208                            11.177956     7.153800e+02
# 247209                                  NaN     7.086256e+01
#
#         Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 0            1.009909e+06       1.180254e+06       59166.887553
# 1            4.370129e+04       5.118342e+04        4043.705718
# 2            4.839631e+04       6.027251e+04         618.808218
# 3            1.147489e+05       2.422413e+05        2602.458243
# 4            1.777571e+04       3.648962e+04          15.587367
# ...                   ...                ...                ...
# 247205       7.916295e-01       2.723205e+00           0.000000
# 247206       3.600343e+01       2.088351e+02          43.850537
# 247207       5.651650e+02       4.620121e+03        1240.670006
# 247208       3.576900e+02       2.924732e+03         935.619995
# 247209       5.314692e+01       4.657836e+02                NaN
#
#         Incremental Volume  Incremental Dollars
# 0             59166.887620         55536.766682
# 1              4043.705725          3966.379893
# 2              1237.616440           999.899905
# 3              2439.804604          3189.355727
# 4                14.613157            22.748004
# ...                    ...                  ...
# 247205            0.000000             0.000000
# 247206           43.850537           188.168592
# 247207          620.335001          4293.378605
# 247208          467.810000          3289.227805
# 247209                 NaN                  NaN
#
# [247210 rows x 24 columns]

# %% [markdown]
# # Replacing the Null Values

# %%
df2018.fillna(0, inplace = True)

# %%
df2020.fillna(0, inplace = True)

# %%
df2022.fillna(0, inplace = True)

# %%
df2018.isnull().sum()
# Out:
# Geography                              0
# Time                                   0
# Product Description                    0
# UPC 13 digit                           0
# Dollar Sales No Merch                  0
# Dollar Sales Any Merch                 0
# Unit Sales No Merch                    0
# Unit Sales Any Merch                   0
# Volume Sales No Merch                  0
# Volume Sales Any Merch                 0
# Price per Unit                         0
# Price per Unit No Merch                0
# Price per Unit Any Merch               0
# Price per Volume                       0
# Price per Volume No Merch              0
# Price per Volume Any Merch             0
# ACV Weighted Distribution No Merch     0
# ACV Weighted Distribution Any Merch    0
# Base Unit Sales                        0
# Base Volume Sales                      0
# Base Dollar Sales                      0
# Incremental Units                      0
# Incremental Volume                     0
# Incremental Dollars                    0
# dtype: int64

# %%
df2020.isnull().sum()
# Out:
# Geography                              0
# Time                                   0
# Product Description                    0
# UPC 13 digit                           0
# Dollar Sales No Merch                  0
# Dollar Sales Any Merch                 0
# Unit Sales No Merch                    0
# Unit Sales Any Merch                   0
# Volume Sales No Merch                  0
# Volume Sales Any Merch                 0
# Price per Unit                         0
# Price per Unit No Merch                0
# Price per Unit Any Merch               0
# Price per Volume                       0
# Price per Volume No Merch              0
# Price per Volume Any Merch             0
# ACV Weighted Distribution No Merch     0
# ACV Weighted Distribution Any Merch    0
# Base Unit Sales                        0
# Base Volume Sales                      0
# Base Dollar Sales                      0
# Incremental Units                      0
# Incremental Volume                     0
# Incremental Dollars                    0
# dtype: int64

# %%
df2022.isnull().sum()
# Out:
# Geography                              0
# Time                                   0
# Product Description                    0
# UPC 13 digit                           0
# Dollar Sales No Merch                  0
# Dollar Sales Any Merch                 0
# Unit Sales No Merch                    0
# Unit Sales Any Merch                   0
# Volume Sales No Merch                  0
# Volume Sales Any Merch                 0
# Price per Unit                         0
# Price per Unit No Merch                0
# Price per Unit Any Merch               0
# Price per Volume                       0
# Price per Volume No Merch              0
# Price per Volume Any Merch             0
# ACV Weighted Distribution No Merch     0
# ACV Weighted Distribution Any Merch    0
# Base Unit Sales                        0
# Base Volume Sales                      0
# Base Dollar Sales                      0
# Incremental Units                      0
# Incremental Volume                     0
# Incremental Dollars                    0
# dtype: int64

# %% [markdown]
# # Statistics of each data set

# %%
df2018[['Dollar Sales No Merch', 'Unit Sales No Merch', 'Price per Unit No Merch']].describe()
# Out:
#        Dollar Sales No Merch  Unit Sales No Merch  Price per Unit No Merch
# count           2.706520e+05         2.706520e+05            270652.000000
# mean            2.092813e+04         6.556351e+03                 3.941502
# std             8.808144e+04         3.381238e+04                 3.087638
# min             0.000000e+00         0.000000e+00                 0.000000
# 25%             1.936852e+02         5.237671e+01                 2.490000
# 50%             1.583725e+03         4.794341e+02                 3.518908
# 75%             1.001506e+04         2.922098e+03                 4.873482
# max             4.218969e+06         2.182544e+06                82.400000

# %%
df2020[['Dollar Sales No Merch', 'Unit Sales No Merch', 'Price per Unit No Merch']].describe()
# Out:
#        Dollar Sales No Merch  Unit Sales No Merch  Price per Unit No Merch
# count           2.683420e+05         2.683420e+05            268342.000000
# mean            2.548426e+04         7.752487e+03                 4.024998
# std             1.163257e+05         4.193194e+04                 2.750889
# min             0.000000e+00         0.000000e+00                 0.000000
# 25%             2.008605e+02         5.221596e+01                 2.682149
# 50%             1.655651e+03         4.770075e+02                 3.616332
# 75%             1.120619e+04         3.211990e+03                 4.942362
# max             5.963802e+06         2.519289e+06               199.990000

# %%
df2022[['Dollar Sales No Merch', 'Unit Sales No Merch', 'Price per Unit No Merch']].describe()
# Out:
#        Dollar Sales No Merch  Unit Sales No Merch  Price per Unit No Merch
# count           2.472100e+05         2.472100e+05            247210.000000
# mean            3.006908e+04         7.319866e+03                 4.676040
# std             1.335760e+05         3.862062e+04                 2.486688
# min             0.000000e+00         0.000000e+00                 0.000000
# 25%             2.555459e+02         5.740887e+01                 3.228211
# 50%             1.950369e+03         4.640000e+02                 4.260518
# 75%             1.301485e+04         3.137044e+03                 5.708953
# max             7.427815e+06         2.645258e+06               199.990000

# %% [markdown]
# # Concatinating the 2018, 2020, 2022 Data Frames into single DataFrame

# %%
df = pd.concat([df2018, df2020, df2022])

# %%
df.isnull().sum()
# Out:
# Geography                              0
# Time                                   0
# Product Description                    0
# UPC 13 digit                           0
# Dollar Sales No Merch                  0
# Dollar Sales Any Merch                 0
# Unit Sales No Merch                    0
# Unit Sales Any Merch                   0
# Volume Sales No Merch                  0
# Volume Sales Any Merch                 0
# Price per Unit                         0
# Price per Unit No Merch                0
# Price per Unit Any Merch               0
# Price per Volume                       0
# Price per Volume No Merch              0
# Price per Volume Any Merch             0
# ACV Weighted Distribution No Merch     0
# ACV Weighted Distribution Any Merch    0
# Base Unit Sales                        0
# Base Volume Sales                      0
# Base Dollar Sales                      0
# Incremental Units                      0
# Incremental Volume                     0
# Incremental Dollars                    0
# dtype: int64

# %% [markdown]
# # Extracting Year and Brands from Time and Product Description column Respectively

# %% [markdown]
# Function for exracting the brand

# %%
def brand(row):
  b = ''
  x = list(row['Product Description'].split(' '))
  b= b+x[0]+x[1]
  return b

# %%
df['Brands'] = df.apply(lambda row: brand(row), axis =1 )

# %%
df['Year'] = pd.to_datetime(df['Time'], format = 'Week Ending %m-%d-%y').dt.year

# %% [markdown]
# Excluding the Total US region as we have individual region data

# %%
c = df['Geography'] != 'Total US - Multi Outlet + Conv'

df = df[c]

# %%
df
# Out:
#                                               Geography                  Time  \
# 66689   California - IRI Standard - Multi Outlet + Conv  Week Ending 01-14-18
# 66690   California - IRI Standard - Multi Outlet + Conv  Week Ending 01-14-18
# 66691   California - IRI Standard - Multi Outlet + Conv  Week Ending 01-14-18
# 66692   California - IRI Standard - Multi Outlet + Conv  Week Ending 01-14-18
# 66693   California - IRI Standard - Multi Outlet + Conv  Week Ending 01-14-18
# ...                                                 ...                   ...
# 247205        West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247206        West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247207        West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247208        West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
# 247209        West - IRI Standard - Multi Outlet + Conv  Week Ending 01-01-23
#
#                                       Product Description   UPC 13 digit  \
# 66689   BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008222
# 66690   BLUE BONNET RFG VEGETABLE OIL SPREAD BOX SPREA...    29000008563
# 66691   BLUE BONNET RFG VEGETABLE OIL SPREAD BOX STICK...    70272006101
# 66692   BLUE BONNET RFG VEGETABLE OIL SPREAD INDIVDL W...    29000008252
# 66693   BLUE BONNET RFG VEGETABLE OIL SPREAD PLASTIC T...    27000009002
# ...                                                   ...            ...
# 247205  WAYFARE RFG BUTTER PLASTIC TUB WHIPPED 12 OZ -...   845681001511
# 247206  COUNTRY CREAM RFG BUTTER PAPER WRAPPED BLOCK 1...    54231100033
# 247207  WESTGOLD RFG BUTTER BOX QUARTER 8 OZ - 9421016...  9421016151221
# 247208  WESTGOLD RFG BUTTER FOIL WRAPPED BLOCK 8 OZ - ...  9421016151231
# 247209  WILDBRINE RFG BUTTER SUBSTITUTE PLASTIC TUB SP...   857859007121
#
#         Dollar Sales No Merch  Dollar Sales Any Merch  Unit Sales No Merch  \
# 66689            43334.842603              500.386062         41683.984239
# 66690              937.860000                0.000000           957.000000
# 66691             1203.674261                0.000000          1215.832586
# 66692              410.350000                0.000000           283.000000
# 66693            16307.833215              212.992915          9140.532793
# ...                       ...                     ...                  ...
# 247205               0.000000                2.723205             0.000000
# 247206             105.951828              291.051912            15.604098
# 247207             252.780000             8660.720000            66.000000
# 247208             227.320000             5986.640000            58.000000
# 247209             465.783566                0.000000            70.862558
#
#         Unit Sales Any Merch  Volume Sales No Merch  Volume Sales Any Merch  \
# 66689             516.354903           41683.984239              516.354903
# 66690               0.000000             957.000000                0.000000
# 66691               0.000000            1215.832586                0.000000
# 66692               0.000000             566.000000                0.000000
# 66693             127.838647            8569.249494              119.848732
# ...                      ...                    ...                     ...
# 247205              1.055506               0.000000                0.791629
# 247206             64.249870              15.604098               64.249870
# 247207           2305.000000              33.000000             1152.500000
# 247208           1593.000000              29.000000              796.500000
# 247209              0.000000              53.146919                0.000000
#
#         ...  ACV Weighted Distribution No Merch  \
# 66689   ...                           53.350912
# 66690   ...                            3.643130
# 66691   ...                            6.586113
# 66692   ...                            0.355747
# 66693   ...                           40.266893
# ...     ...                                 ...
# 247205  ...                            0.000000
# 247206  ...                            0.107566
# 247207  ...                            0.511593
# 247208  ...                            0.533303
# 247209  ...                            0.978980
#
#         ACV Weighted Distribution Any Merch  Base Unit Sales  \
# 66689                              1.202991     41987.074776
# 66690                              0.000000       957.000000
# 66691                              0.000000      1215.832586
# 66692                              0.000000       283.000000
# 66693                              0.611094      9242.986113
# ...                                     ...              ...
# 247205                             0.050271         1.055506
# 247206                             0.169880        36.003432
# 247207                            11.384921      1130.329994
# 247208                            11.177956       715.380005
# 247209                             0.000000        70.862558
#
#         Base Volume Sales  Base Dollar Sales  Incremental Units  \
# 66689        41987.074775       43757.029184         213.264366
# 66690          957.000000         937.860000           0.000000
# 66691         1215.832586        1203.674261           0.000000
# 66692          566.000000         410.350000           0.000000
# 66693         8665.299481       16477.454852          25.385327
# ...                   ...                ...                ...
# 247205           0.791629           2.723205           0.000000
# 247206          36.003432         208.835148          43.850537
# 247207         565.164999        4620.121395        1240.670006
# 247208         357.690000        2924.732195         935.619995
# 247209          53.146919         465.783566           0.000000
#
#         Incremental Volume  Incremental Dollars        Brands  Year
# 66689           213.264367            78.199482    BLUEBONNET  2018
# 66690             0.000000             0.000000    BLUEBONNET  2018
# 66691             0.000000             0.000000    BLUEBONNET  2018
# 66692             0.000000             0.000000    BLUEBONNET  2018
# 66693            23.798744            43.371278    BLUEBONNET  2018
# ...                    ...                  ...           ...   ...
# 247205            0.000000             0.000000    WAYFARERFG  2023
# 247206           43.850537           188.168592  COUNTRYCREAM  2023
# 247207          620.335001          4293.378605   WESTGOLDRFG  2023
# 247208          467.810000          3289.227805   WESTGOLDRFG  2023
# 247209            0.000000             0.000000  WILDBRINERFG  2023
#
# [598848 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Geography', 'Time', 'Product Description', 'UPC 13 digit',
#        'Dollar Sales No Merch', 'Dollar Sales Any Merch',
#        'Unit Sales No Merch', 'Unit Sales Any Merch', 'Volume Sales No Merch',
#        'Volume Sales Any Merch', 'Price per Unit', 'Price per Unit No Merch',
#        'Price per Unit Any Merch', 'Price per Volume',
#        'Price per Volume No Merch', 'Price per Volume Any Merch',
#        'ACV Weighted Distribution No Merch',
#        'ACV Weighted Distribution Any Merch', 'Base Unit Sales',
#        'Base Volume Sales', 'Base Dollar Sales', 'Incremental Units',
#        'Incremental Volume', 'Incremental Dollars', 'Brands', 'Year'],
#       dtype='object')

# %% [markdown]
# # Correlation

# %%
corr_df = df.corr()

# %%
fig, ax = plt.subplots(figsize=(15,17)) 
sns.heatmap(corr_df, annot=True, ax=ax)
plt.show()

# %% [markdown]
# # Dummies for Brands, Regions and Years

# %%
df_dummy = pd.get_dummies(df, columns=['Geography','Brands','Year'])

# %%
l = list(df_dummy.columns)
print(len(l))
# Out:
# 409

# %%
print(l)
# Out:
# ['Time', 'Product Description', 'UPC 13 digit', 'Dollar Sales No Merch', 'Dollar Sales Any Merch', 'Unit Sales No Merch', 'Unit Sales Any Merch', 'Volume Sales No Merch', 'Volume Sales Any Merch', 'Price per Unit', 'Price per Unit No Merch', 'Price per Unit Any Merch', 'Price per Volume', 'Price per Volume No Merch', 'Price per Volume Any Merch', 'ACV Weighted Distribution No Merch', 'ACV Weighted Distribution Any Merch', 'Base Unit Sales', 'Base Volume Sales', 'Base Dollar Sales', 'Incremental Units', 'Incremental Volume', 'Incremental Dollars', 'Geography_California - IRI Standard - Multi Outlet + Conv', 'Geography_Great Lakes - IRI Standard - Multi Outlet + Conv', 'Geography_Mid-South - IRI Standard - Multi Outlet + Conv', 'Geography_Northeast - IRI Standard - Multi Outlet + Conv', 'Geography_Plains - IRI Standard - Multi Outlet + Conv', 'Geography_South Central - IRI Standard - Multi Outlet + Conv', 'Geography_Southeast - IRI Standard - Multi Outlet + Conv', 'Geography_West - IRI Standard - Multi Outlet + Conv', 'Brands_AAKFOOD', 'Brands_ADMIRATIONRFG', 'Brands_ALCAMRFG', 'Brands_ALHALOUB', 'Brands_ALLBRAND', 'Brands_ALPENROSE', 'Brands_ALTADENA', 'Brands_AMERICANBEAUTY', 'Brands_AMISHBUTTER', 'Brands_AMISHCOUNTRY', 'Brands_AMISHVALLEY', 'Brands_AMISHWEDDING', 'Brands_AMPIRFG', 'Brands_ANCHORRFG', 'Brands_ANDERSONRFG', 'Brands_ANDREW&', 'Brands_ARETHUSAFARM', 'Brands_AUXDELICES', 'Brands_BALADERFG', 'Brands_BANDIRFG', 'Brands_BANNERBUTTER', 'Brands_BANQUETRFG', 'Brands_BANSIRFG', 'Brands_BEAVERMEADOW', 'Brands_BENECOLRFG', 'Brands_BENNETTSBUTTER', 'Brands_BERKELEYFARMS', 'Brands_BETTERBUTTER', 'Brands_BEURDELLRFG', 'Brands_BEURREMONT83', 'Brands_BGAN', 'Brands_BIGGSAND', 'Brands_BIOLIFERFG', 'Brands_BLUEBONNET', 'Brands_BONGARDSRFG', 'Brands_BORDENRFG', 'Brands_BREAKSTONESRFG', 'Brands_BRETHRENBUTTER', 'Brands_BROOKLYNBUTTERY', 'Brands_BRUMMEL&', 'Brands_BULLETPROOFRFG', 'Brands_BURNBUTTER', 'Brands_BUTTERCUISINE', 'Brands_BUTTERCUPS', 'Brands_BUTTERFIELDRFG', 'Brands_BYRNEDAIRY', 'Brands_CABOTRFG', 'Brands_CACHEVALLEY', 'Brands_CADIARFG', 'Brands_CALDERDAIRY', 'Brands_CALIFIAFARMS', 'Brands_CALIFORNIADAIRIES', 'Brands_CANOLAHARVEST', 'Brands_CANOLEORFG', 'Brands_CARRIBEXRFG', 'Brands_CARRINGTONFARMS', 'Brands_CARRVALLEY', 'Brands_CASCOBAY', 'Brands_CASSCLAY', 'Brands_CELEBRITYRFG', 'Brands_CELLESSUR', 'Brands_CHALLENGEBUTTER', 'Brands_CHALLENGERFG', 'Brands_CHARLESTONSOWN', 'Brands_CHEFROBERT', 'Brands_CHEFSHAMY', 'Brands_CHIMAYRFG', 'Brands_CLOVERDALE', 'Brands_CLOVERSONOMA', 'Brands_COLLIERSRFG', 'Brands_COUNTRYBRAND', 'Brands_COUNTRYCREAM', 'Brands_COUNTRYCREAMERY', 'Brands_COUNTRYCROCK', 'Brands_COUNTRYDELIGHT', 'Brands_COUNTRYFRESH', 'Brands_COUNTRYMAID', 'Brands_COUNTRYPATTIES', 'Brands_COUNTRYPREMIUM', 'Brands_COUNTRYTRADITION', 'Brands_COWSCREAMERY', 'Brands_CRACOVIARFG', 'Brands_CREEKSIDERFG', 'Brands_CREMERIECLASSIQUE', 'Brands_CRISOLRFG', 'Brands_CRYSTALFARMS', 'Brands_CRYSTALRFG', 'Brands_DAIRYFRESH', 'Brands_DAIRYGOLDRFG', 'Brands_DAIRYPURE', 'Brands_DANCYSFANCY', 'Brands_DANISHCREAMERY', 'Brands_DANISHMAID', 'Brands_DANZEISENDAIRY', 'Brands_DAPHNESCREAMERY', 'Brands_DARIGOLDRFG', 'Brands_DAROSARIO', 'Brands_DARTAGNANRFG', 'Brands_DELAMEREDAIRY', 'Brands_DELITIARFG', 'Brands_DELLAHRFG', 'Brands_DEMILL', 'Brands_DEWFRESH', 'Brands_DIMOCKDAIRY', 'Brands_DINNERBELL', 'Brands_DOBRERFG', 'Brands_DOWNEYSRFG', 'Brands_DUCHESSRFG', 'Brands_DUTCHFARMS', 'Brands_EARTHBALANCE', 'Brands_EBERHARDSRFG', 'Brands_EDENRFG', 'Brands_ELLATINO', 'Brands_ELLE&', 'Brands_ELLSWORTHRFG', 'Brands_ENGLISHDOUBLE', 'Brands_EPICUREANRFG', 'Brands_FABRIQUEDELICES', 'Brands_FALFURRIASRFG', 'Brands_FARMBESTRFG', 'Brands_FARMHOUSEKITCHENS', 'Brands_FARMSCREAMERY', 'Brands_FERMARFG', 'Brands_FERRARINIRFG', 'Brands_FINLANDIARFG', 'Brands_FIRSTPRIZE', 'Brands_FLEISCHMANNSRFG', 'Brands_FLORARFG', 'Brands_FLOWERBRAND', 'Brands_FONDO', 'Brands_FORAGERPROJECT', 'Brands_FOURSEASONS', 'Brands_FRENTELBUTTER', 'Brands_FRESHCHURNED', 'Brands_FRESHMADE', ...

# %% [markdown]
# # Hypothesis

# %% [markdown]
# H0: These is no significat Difference in unit sales between 2018 and 2020

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Load two dataframes


# Extract 'Unit Sales No Merch' columns from each dataframe
unit_sales2018 = df2018['Unit Sales No Merch']
unit_sales2020 = df2020['Unit Sales No Merch']

# Perform two-sample t-test
t_stat, p_value = ttest_ind(unit_sales2018, unit_sales2020, equal_var=False)

# Print results
print('t-statistic 2018-2020: {:.3f}'.format(t_stat))
print('p-value 2018-2020: {:.3f}'.format(p_value))
# Out:
# t-statistic 2018-2020: -11.522
# p-value 2018-2020: 0.000

# %% [markdown]
# H0: These is no significat Difference in unit sales between 2018 and 2022

# %%
# Extract 'Unit Sales No Merch' columns from each dataframe
unit_sales2018 = df2018['Unit Sales No Merch']
unit_sales2022 = df2022['Unit Sales No Merch']

# Perform two-sample t-test
t_stat, p_value = ttest_ind(unit_sales2018, unit_sales2022, equal_var=False)

# Print results
print('t-statistic 2018-2022: {:.3f}'.format(t_stat))
print('p-value 2018-2022: {:.3f}'.format(p_value))
# Out:
# t-statistic 2018-2022: -7.539
# p-value 2018-2022: 0.000

# %% [markdown]
# H0: These is no significat Difference in unit sales between 2020 and 2022

# %%
unit_sales2020 = df2020['Unit Sales No Merch']
unit_sales2022 = df2022['Unit Sales No Merch']

# Perform two-sample t-test
t_stat, p_value = ttest_ind(unit_sales2020, unit_sales2022, equal_var=False)

# Print results
print('t-statistic 2020-2022: {:.3f}'.format(t_stat))
print('p-value 2020-2022: {:.3f}'.format(p_value))
# Out:
# t-statistic 2020-2022: 3.856
# p-value 2020-2022: 0.000

# %% [markdown]
# Anova test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# create a formula for the ANOVA model
formula = 'Q("Unit Sales No Merch") ~ C(Geography)'

# fit the ANOVA model using ordinary least squares (OLS)
modelols2018 = ols(formula=formula, data=df2018).fit()

# compute ANOVA table
anova_table2018 = sm.stats.anova_lm(modelols2018, typ=2)

# print the ANOVA table
print("   --------------  ANOVA test 2018 -------------  ")
print(anova_table2018)
# Out:
#    --------------  ANOVA test 2018 -------------
#                     sum_sq        df           F  PR(>F)
# C(Geography)  4.200045e+12       8.0  465.516244     0.0
# Residual      3.052291e+14  270643.0         NaN     NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# create a formula for the ANOVA model
formula = 'Q("Unit Sales No Merch") ~ C(Geography)'

# fit the ANOVA model using ordinary least squares (OLS)
modelols2020 = ols(formula=formula, data=df2020).fit()

# compute ANOVA table
anova_table2020 = sm.stats.anova_lm(modelols2020, typ=2)

# print the ANOVA table
print("   --------------  ANOVA test 2020  -------------  ")
print(anova_table2020)
# Out:
#    --------------  ANOVA test 2020  -------------
#                     sum_sq        df           F  PR(>F)
# C(Geography)  6.378447e+12       8.0  459.656416     0.0
# Residual      4.654422e+14  268333.0         NaN     NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# create a formula for the ANOVA model
formula = 'Q("Unit Sales No Merch") ~ C(Geography)'

# fit the ANOVA model using ordinary least squares (OLS)
modelols2022 = ols(formula=formula, data=df2022).fit()

# compute ANOVA table
anova_table2022 = sm.stats.anova_lm(modelols2022, typ=2)

# print the ANOVA table
print("   --------------  ANOVA test 2022  -------------  ")
print(anova_table2022)
# Out:
#    --------------  ANOVA test 2022  -------------
#                     sum_sq        df          F  PR(>F)
# C(Geography)  5.644077e+12       8.0  480.34098     0.0
# Residual      3.630810e+14  247201.0        NaN     NaN

# %% [markdown]
# # Building a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns

# %%
l = list(df_dummy.columns)

r = ['Time',
 'Product Description',
 'UPC 13 digit',
 'Dollar Sales No Merch',
 'Dollar Sales Any Merch',
 'Unit Sales No Merch', 'Unit Sales Any Merch', 'Price per Unit','Price per Volume',
 'Price per Volume No Merch',
 'Price per Volume Any Merch',
 'Base Unit Sales',
 'Volume Sales No Merch', 'Volume Sales Any Merch',
 'Base Dollar Sales',
 'Incremental Units',
 'Incremental Volume',
 'Incremental Dollars']

for i in r:
  l.remove(i)

# %%
print(l)
# Out:
# ['Price per Unit No Merch', 'Price per Unit Any Merch', 'ACV Weighted Distribution No Merch', 'ACV Weighted Distribution Any Merch', 'Base Volume Sales', 'Geography_California - IRI Standard - Multi Outlet + Conv', 'Geography_Great Lakes - IRI Standard - Multi Outlet + Conv', 'Geography_Mid-South - IRI Standard - Multi Outlet + Conv', 'Geography_Northeast - IRI Standard - Multi Outlet + Conv', 'Geography_Plains - IRI Standard - Multi Outlet + Conv', 'Geography_South Central - IRI Standard - Multi Outlet + Conv', 'Geography_Southeast - IRI Standard - Multi Outlet + Conv', 'Geography_West - IRI Standard - Multi Outlet + Conv', 'Brands_AAKFOOD', 'Brands_ADMIRATIONRFG', 'Brands_ALCAMRFG', 'Brands_ALHALOUB', 'Brands_ALLBRAND', 'Brands_ALPENROSE', 'Brands_ALTADENA', 'Brands_AMERICANBEAUTY', 'Brands_AMISHBUTTER', 'Brands_AMISHCOUNTRY', 'Brands_AMISHVALLEY', 'Brands_AMISHWEDDING', 'Brands_AMPIRFG', 'Brands_ANCHORRFG', 'Brands_ANDERSONRFG', 'Brands_ANDREW&', 'Brands_ARETHUSAFARM', 'Brands_AUXDELICES', 'Brands_BALADERFG', 'Brands_BANDIRFG', 'Brands_BANNERBUTTER', 'Brands_BANQUETRFG', 'Brands_BANSIRFG', 'Brands_BEAVERMEADOW', 'Brands_BENECOLRFG', 'Brands_BENNETTSBUTTER', 'Brands_BERKELEYFARMS', 'Brands_BETTERBUTTER', 'Brands_BEURDELLRFG', 'Brands_BEURREMONT83', 'Brands_BGAN', 'Brands_BIGGSAND', 'Brands_BIOLIFERFG', 'Brands_BLUEBONNET', 'Brands_BONGARDSRFG', 'Brands_BORDENRFG', 'Brands_BREAKSTONESRFG', 'Brands_BRETHRENBUTTER', 'Brands_BROOKLYNBUTTERY', 'Brands_BRUMMEL&', 'Brands_BULLETPROOFRFG', 'Brands_BURNBUTTER', 'Brands_BUTTERCUISINE', 'Brands_BUTTERCUPS', 'Brands_BUTTERFIELDRFG', 'Brands_BYRNEDAIRY', 'Brands_CABOTRFG', 'Brands_CACHEVALLEY', 'Brands_CADIARFG', 'Brands_CALDERDAIRY', 'Brands_CALIFIAFARMS', 'Brands_CALIFORNIADAIRIES', 'Brands_CANOLAHARVEST', 'Brands_CANOLEORFG', 'Brands_CARRIBEXRFG', 'Brands_CARRINGTONFARMS', 'Brands_CARRVALLEY', 'Brands_CASCOBAY', 'Brands_CASSCLAY', 'Brands_CELEBRITYRFG', 'Brands_CELLESSUR', 'Brands_CHALLENGEBUTTER', 'Brands_CHALLENGERFG', 'Brands_CHARLESTONSOWN', 'Brands_CHEFROBERT', 'Brands_CHEFSHAMY', 'Brands_CHIMAYRFG', 'Brands_CLOVERDALE', 'Brands_CLOVERSONOMA', 'Brands_COLLIERSRFG', 'Brands_COUNTRYBRAND', 'Brands_COUNTRYCREAM', 'Brands_COUNTRYCREAMERY', 'Brands_COUNTRYCROCK', 'Brands_COUNTRYDELIGHT', 'Brands_COUNTRYFRESH', 'Brands_COUNTRYMAID', 'Brands_COUNTRYPATTIES', 'Brands_COUNTRYPREMIUM', 'Brands_COUNTRYTRADITION', 'Brands_COWSCREAMERY', 'Brands_CRACOVIARFG', 'Brands_CREEKSIDERFG', 'Brands_CREMERIECLASSIQUE', 'Brands_CRISOLRFG', 'Brands_CRYSTALFARMS', 'Brands_CRYSTALRFG', 'Brands_DAIRYFRESH', 'Brands_DAIRYGOLDRFG', 'Brands_DAIRYPURE', 'Brands_DANCYSFANCY', 'Brands_DANISHCREAMERY', 'Brands_DANISHMAID', 'Brands_DANZEISENDAIRY', 'Brands_DAPHNESCREAMERY', 'Brands_DARIGOLDRFG', 'Brands_DAROSARIO', 'Brands_DARTAGNANRFG', 'Brands_DELAMEREDAIRY', 'Brands_DELITIARFG', 'Brands_DELLAHRFG', 'Brands_DEMILL', 'Brands_DEWFRESH', 'Brands_DIMOCKDAIRY', 'Brands_DINNERBELL', 'Brands_DOBRERFG', 'Brands_DOWNEYSRFG', 'Brands_DUCHESSRFG', 'Brands_DUTCHFARMS', 'Brands_EARTHBALANCE', 'Brands_EBERHARDSRFG', 'Brands_EDENRFG', 'Brands_ELLATINO', 'Brands_ELLE&', 'Brands_ELLSWORTHRFG', 'Brands_ENGLISHDOUBLE', 'Brands_EPICUREANRFG', 'Brands_FABRIQUEDELICES', 'Brands_FALFURRIASRFG', 'Brands_FARMBESTRFG', 'Brands_FARMHOUSEKITCHENS', 'Brands_FARMSCREAMERY', 'Brands_FERMARFG', 'Brands_FERRARINIRFG', 'Brands_FINLANDIARFG', 'Brands_FIRSTPRIZE', 'Brands_FLEISCHMANNSRFG', 'Brands_FLORARFG', 'Brands_FLOWERBRAND', 'Brands_FONDO', 'Brands_FORAGERPROJECT', 'Brands_FOURSEASONS', 'Brands_FRENTELBUTTER', 'Brands_FRESHCHURNED', 'Brands_FRESHMADE', 'Brands_GEVINAFARMS', 'Brands_GLAVMASLOPROMRFG', 'Brands_GLENSTALFOODS', 'Brands_GLENVIEWFARMS', 'Brands_GOLDENDELICIOUS', 'Brands_GOLDENGOODNESS', 'Brands_GOLDENRAY', 'Brands_GOLDENWEST', 'Brands_GOLDN', 'Brands_GOYARFG', 'Brands_GRANDCRU', 'Brands_GRANDMAALICES', 'Brands_GRASSLANDRFG', 'Brands_GREENFIELDSRFG', 'Brands_GREENVALLEY', 'Brands_GUERNSEYRFG', 'Brands_GUIDASRFG', 'Brands_HANSENSFARM' ...

# %%
var = l
x= pd.DataFrame(df_dummy[var])
y= pd.DataFrame(df_dummy['Unit Sales No Merch'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size= 0.2, random_state=5)

# %%
regressor = LinearRegression()
model =regressor.fit(x_train, y_train)

# %%
v = pd.DataFrame(model.coef_, index=['Co-efficients']).transpose()
w = pd.DataFrame(x_train.columns, columns = ['Attributes'])

# %%
coeff_lrm= pd.concat([w,v], axis=1,)
coeff_lrm
# Out:
#                               Attributes  Co-efficients
# 0                Price per Unit No Merch  -3.059205e+02
# 1               Price per Unit Any Merch  -3.567943e+02
# 2     ACV Weighted Distribution No Merch   2.419792e+02
# 3    ACV Weighted Distribution Any Merch  -2.267164e+02
# 4                      Base Volume Sales   5.714860e-01
# ..                                   ...            ...
# 386                            Year_2019  -3.966543e+08
# 387                            Year_2020  -3.966540e+08
# 388                            Year_2021  -3.966541e+08
# 389                            Year_2022  -3.966537e+08
# 390                            Year_2023  -3.966536e+08
#
# [391 rows x 2 columns]

# %%
y_pred = model.predict(x_test)

# %%
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
# Out:
#  Accuracy of the model is 81.18

# %%
model.score(x_test, y_test)
# Out:
# 0.8117708441343774

# %%
sns.regplot(x=y_test,y=y_pred,ci=None,scatter_kws={"color": "green"}, line_kws={"color": "red"});
plt.title("Linear Regression Model")
plt.xlabel("Unit Sales No Merch (Actual Value)")
plt.ylabel("Unit Sales No Merch (Predicted Value)")
# Out:
# Text(0, 0.5, 'Unit Sales No Merch (Predicted Value)')

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import LassoCV,Lasso

# %%
l = list(df_dummy.columns)

r = ['Time',
 'Product Description',
 'UPC 13 digit',
 'Dollar Sales No Merch',
 'Dollar Sales Any Merch',
 'Unit Sales No Merch', 'Unit Sales Any Merch', 'Price per Unit','Price per Volume',
 'Price per Volume No Merch',
 'Price per Volume Any Merch',
 'Base Unit Sales',
 'Volume Sales No Merch', 'Volume Sales Any Merch',
 'Base Dollar Sales',
 'Base Volume Sales',
 'Incremental Units',
 'Incremental Volume',
 'Incremental Dollars']

for i in r:
  l.remove(i)

# %%
print(l)
# Out:
# ['Price per Unit No Merch', 'Price per Unit Any Merch', 'ACV Weighted Distribution No Merch', 'ACV Weighted Distribution Any Merch', 'Geography_California - IRI Standard - Multi Outlet + Conv', 'Geography_Great Lakes - IRI Standard - Multi Outlet + Conv', 'Geography_Mid-South - IRI Standard - Multi Outlet + Conv', 'Geography_Northeast - IRI Standard - Multi Outlet + Conv', 'Geography_Plains - IRI Standard - Multi Outlet + Conv', 'Geography_South Central - IRI Standard - Multi Outlet + Conv', 'Geography_Southeast - IRI Standard - Multi Outlet + Conv', 'Geography_West - IRI Standard - Multi Outlet + Conv', 'Brands_AAKFOOD', 'Brands_ADMIRATIONRFG', 'Brands_ALCAMRFG', 'Brands_ALHALOUB', 'Brands_ALLBRAND', 'Brands_ALPENROSE', 'Brands_ALTADENA', 'Brands_AMERICANBEAUTY', 'Brands_AMISHBUTTER', 'Brands_AMISHCOUNTRY', 'Brands_AMISHVALLEY', 'Brands_AMISHWEDDING', 'Brands_AMPIRFG', 'Brands_ANCHORRFG', 'Brands_ANDERSONRFG', 'Brands_ANDREW&', 'Brands_ARETHUSAFARM', 'Brands_AUXDELICES', 'Brands_BALADERFG', 'Brands_BANDIRFG', 'Brands_BANNERBUTTER', 'Brands_BANQUETRFG', 'Brands_BANSIRFG', 'Brands_BEAVERMEADOW', 'Brands_BENECOLRFG', 'Brands_BENNETTSBUTTER', 'Brands_BERKELEYFARMS', 'Brands_BETTERBUTTER', 'Brands_BEURDELLRFG', 'Brands_BEURREMONT83', 'Brands_BGAN', 'Brands_BIGGSAND', 'Brands_BIOLIFERFG', 'Brands_BLUEBONNET', 'Brands_BONGARDSRFG', 'Brands_BORDENRFG', 'Brands_BREAKSTONESRFG', 'Brands_BRETHRENBUTTER', 'Brands_BROOKLYNBUTTERY', 'Brands_BRUMMEL&', 'Brands_BULLETPROOFRFG', 'Brands_BURNBUTTER', 'Brands_BUTTERCUISINE', 'Brands_BUTTERCUPS', 'Brands_BUTTERFIELDRFG', 'Brands_BYRNEDAIRY', 'Brands_CABOTRFG', 'Brands_CACHEVALLEY', 'Brands_CADIARFG', 'Brands_CALDERDAIRY', 'Brands_CALIFIAFARMS', 'Brands_CALIFORNIADAIRIES', 'Brands_CANOLAHARVEST', 'Brands_CANOLEORFG', 'Brands_CARRIBEXRFG', 'Brands_CARRINGTONFARMS', 'Brands_CARRVALLEY', 'Brands_CASCOBAY', 'Brands_CASSCLAY', 'Brands_CELEBRITYRFG', 'Brands_CELLESSUR', 'Brands_CHALLENGEBUTTER', 'Brands_CHALLENGERFG', 'Brands_CHARLESTONSOWN', 'Brands_CHEFROBERT', 'Brands_CHEFSHAMY', 'Brands_CHIMAYRFG', 'Brands_CLOVERDALE', 'Brands_CLOVERSONOMA', 'Brands_COLLIERSRFG', 'Brands_COUNTRYBRAND', 'Brands_COUNTRYCREAM', 'Brands_COUNTRYCREAMERY', 'Brands_COUNTRYCROCK', 'Brands_COUNTRYDELIGHT', 'Brands_COUNTRYFRESH', 'Brands_COUNTRYMAID', 'Brands_COUNTRYPATTIES', 'Brands_COUNTRYPREMIUM', 'Brands_COUNTRYTRADITION', 'Brands_COWSCREAMERY', 'Brands_CRACOVIARFG', 'Brands_CREEKSIDERFG', 'Brands_CREMERIECLASSIQUE', 'Brands_CRISOLRFG', 'Brands_CRYSTALFARMS', 'Brands_CRYSTALRFG', 'Brands_DAIRYFRESH', 'Brands_DAIRYGOLDRFG', 'Brands_DAIRYPURE', 'Brands_DANCYSFANCY', 'Brands_DANISHCREAMERY', 'Brands_DANISHMAID', 'Brands_DANZEISENDAIRY', 'Brands_DAPHNESCREAMERY', 'Brands_DARIGOLDRFG', 'Brands_DAROSARIO', 'Brands_DARTAGNANRFG', 'Brands_DELAMEREDAIRY', 'Brands_DELITIARFG', 'Brands_DELLAHRFG', 'Brands_DEMILL', 'Brands_DEWFRESH', 'Brands_DIMOCKDAIRY', 'Brands_DINNERBELL', 'Brands_DOBRERFG', 'Brands_DOWNEYSRFG', 'Brands_DUCHESSRFG', 'Brands_DUTCHFARMS', 'Brands_EARTHBALANCE', 'Brands_EBERHARDSRFG', 'Brands_EDENRFG', 'Brands_ELLATINO', 'Brands_ELLE&', 'Brands_ELLSWORTHRFG', 'Brands_ENGLISHDOUBLE', 'Brands_EPICUREANRFG', 'Brands_FABRIQUEDELICES', 'Brands_FALFURRIASRFG', 'Brands_FARMBESTRFG', 'Brands_FARMHOUSEKITCHENS', 'Brands_FARMSCREAMERY', 'Brands_FERMARFG', 'Brands_FERRARINIRFG', 'Brands_FINLANDIARFG', 'Brands_FIRSTPRIZE', 'Brands_FLEISCHMANNSRFG', 'Brands_FLORARFG', 'Brands_FLOWERBRAND', 'Brands_FONDO', 'Brands_FORAGERPROJECT', 'Brands_FOURSEASONS', 'Brands_FRENTELBUTTER', 'Brands_FRESHCHURNED', 'Brands_FRESHMADE', 'Brands_GEVINAFARMS', 'Brands_GLAVMASLOPROMRFG', 'Brands_GLENSTALFOODS', 'Brands_GLENVIEWFARMS', 'Brands_GOLDENDELICIOUS', 'Brands_GOLDENGOODNESS', 'Brands_GOLDENRAY', 'Brands_GOLDENWEST', 'Brands_GOLDN', 'Brands_GOYARFG', 'Brands_GRANDCRU', 'Brands_GRANDMAALICES', 'Brands_GRASSLANDRFG', 'Brands_GREENFIELDSRFG', 'Brands_GREENVALLEY', 'Brands_GUERNSEYRFG', 'Brands_GUIDASRFG', 'Brands_HANSENSFARM', 'Brands_HAOLAMRFG', ...

# %%
var = l
xlasso= pd.DataFrame(df_dummy[var])
ylasso= pd.DataFrame(df_dummy['Unit Sales No Merch'])

# %%
x_trainlasso, x_testlasso, y_trainlasso, y_testlasso = train_test_split(xlasso,ylasso,test_size= 0.2,random_state=5)

# %%
# Create a Lasso Regression model with cross-validation
lasso_cv_model = LassoCV(cv=5)

# Fit the model on the training set
lasso_cv_model.fit(x_trainlasso, y_trainlasso)

# Select the optimal value of alpha
alpha_optimal = lasso_cv_model.alpha_

# Create a Lasso Regression model with the optimal value of alpha
lasso_model = Lasso(alpha=alpha_optimal, max_iter=10000)

# Fit the model on the training set
lasso_model.fit(x_trainlasso, y_trainlasso)

# Predict the target variable for the test set
y_pred_lasso = lasso_model.predict(x_testlasso)

# Calculate the R^2 score on the test set
score_lasso = lasso_model.score(x_testlasso, y_testlasso)

# Print the R^2 score and the optimal value of alpha
print("R^2 score for Lasso Regression model:", score_lasso)
print("Optimal value of alpha:", alpha_optimal)
# Out:
# R^2 score for Lasso Regression model: 0.382651774604987
# Optimal value of alpha: 149.7804344576788

# %%
print(alpha_optimal)
# Out:
# 149.7804344576788

# %%
lasso_coef = pd.DataFrame(columns=["Feature", "Coefficient"])

# %%
for i in range(len(l)):
  print('{} : {}'.format(l[i], lasso_model.coef_[i].transpose()) )
  feature = l[i]
  coefficient = lasso_model.coef_[i]
  lasso_coef = lasso_coef.append({'Feature': feature, 'Coefficient': coefficient}, ignore_index=True)
# Out:
# Price per Unit No Merch : -0.0
# Price per Unit Any Merch : -483.68124595182695
# ACV Weighted Distribution No Merch : 615.7601133642759
# ACV Weighted Distribution Any Merch : 178.90759772744133
# Geography_California - IRI Standard - Multi Outlet + Conv : -142.7100806713668
# Geography_Great Lakes - IRI Standard - Multi Outlet + Conv : 0.0
# Geography_Mid-South - IRI Standard - Multi Outlet + Conv : 0.0
# Geography_Northeast - IRI Standard - Multi Outlet + Conv : 333.9524282286551
# Geography_Plains - IRI Standard - Multi Outlet + Conv : -890.8808998272059
# Geography_South Central - IRI Standard - Multi Outlet + Conv : 0.0
# Geography_Southeast - IRI Standard - Multi Outlet + Conv : 0.0
# Geography_West - IRI Standard - Multi Outlet + Conv : -0.0
# Brands_AAKFOOD : 0.0
# Brands_ADMIRATIONRFG : 0.0
# Brands_ALCAMRFG : 0.0
# Brands_ALHALOUB : 0.0
# Brands_ALLBRAND : 0.0
# Brands_ALPENROSE : 0.0
# Brands_ALTADENA : 0.0
# Brands_AMERICANBEAUTY : 0.0
# Brands_AMISHBUTTER : 0.0
# Brands_AMISHCOUNTRY : 0.0
# Brands_AMISHVALLEY : 0.0
# Brands_AMISHWEDDING : 0.0
# Brands_AMPIRFG : 0.0
# Brands_ANCHORRFG : 0.0
# Brands_ANDERSONRFG : 0.0
# Brands_ANDREW& : 0.0
# Brands_ARETHUSAFARM : 0.0
# Brands_AUXDELICES : 0.0
# Brands_BALADERFG : 0.0
# Brands_BANDIRFG : 0.0
# Brands_BANNERBUTTER : 0.0
# Brands_BANQUETRFG : 0.0
# Brands_BANSIRFG : 0.0
# Brands_BEAVERMEADOW : 0.0
# Brands_BENECOLRFG : -0.0
# Brands_BENNETTSBUTTER : 0.0
# Brands_BERKELEYFARMS : 0.0
# Brands_BETTERBUTTER : 0.0
# Brands_BEURDELLRFG : 0.0
# Brands_BEURREMONT83 : 0.0
# Brands_BGAN : 0.0
# Brands_BIGGSAND : 0.0
# Brands_BIOLIFERFG : 0.0
# Brands_BLUEBONNET : 6636.213050299841
# Brands_BONGARDSRFG : 0.0
# Brands_BORDENRFG : 0.0
# Brands_BREAKSTONESRFG : -0.0
# Brands_BRETHRENBUTTER : 0.0
# Brands_BROOKLYNBUTTERY : 0.0
# Brands_BRUMMEL& : -0.0
# Brands_BULLETPROOFRFG : 0.0
# Brands_BURNBUTTER : 0.0
# Brands_BUTTERCUISINE : 0.0
# Brands_BUTTERCUPS : 0.0
# Brands_BUTTERFIELDRFG : 0.0
# Brands_BYRNEDAIRY : 0.0
# Brands_CABOTRFG : 0.0
# Brands_CACHEVALLEY : 0.0
# Brands_CADIARFG : 0.0
# Brands_CALDERDAIRY : 0.0
# Brands_CALIFIAFARMS : 0.0
# Brands_CALIFORNIADAIRIES : 0.0
# Brands_CANOLAHARVEST : -0.0
# Brands_CANOLEORFG : 0.0
# Brands_CARRIBEXRFG : 0.0
# Brands_CARRINGTONFARMS : 0.0
# Brands_CARRVALLEY : 0.0
# Brands_CASCOBAY : 0.0
# Brands_CASSCLAY : 0.0
# Brands_CELEBRITYRFG : 0.0
# Brands_CELLESSUR : 0.0
# Brands_CHALLENGEBUTTER : -0.0
# Brands_CHALLENGERFG : 0.0
# Brands_CHARLESTONSOWN : 0.0
# Brands_CHEFROBERT : 0.0
# Brands_CHEFSHAMY : 0.0
# Brands_CHIMAYRFG : 0.0
# Brands_CLOVERDALE : 0.0
# Brands_CLOVERSONOMA : 0.0
# Brands_COLLIERSRFG : 0.0
# Brands_COUNTRYBRAND : 0.0
# Brands_COUNTRYCREAM : 0.0
# Brands_COUNTRYCREAMERY : 0.0
# Brands_COUNTRYCROCK : 0.0
# Brands_COUNTRYDELIGHT : 0.0
# Brands_COUNTRYFRESH : 0.0
# Brands_COUNTRYMAID : 0.0
# Brands_COUNTRYPATTIES : 0.0
# Brands_COUNTRYPREMIUM : 0.0
# Brands_COUNTRYTRADITION : 0.0
# Brands_COWSCREAMERY : 0.0
# Brands_CRACOVIARFG : 0.0
# Brands_CREEKSIDERFG : 0.0
# Brands_CREMERIECLASSIQUE : 0.0
# Brands_CRISOLRFG : 0.0
# Brands_CRYSTALFARMS : 0.0
# Brands_CRYSTALRFG : 0.0
# Brands_DAIRYFRESH : 0.0
# Brands_DAIRYGOLDRFG : 0.0
# Brands_DAIRYPURE : 0.0
# Brands_DANCYSFANCY : 0.0
# Brands_DANISHCREAMERY : -0.0
# Brands_DANISHMAID : 0.0
# Brands_DANZEISENDAIRY : 0.0
# Brands_DAPHNESCREAMERY : 0.0
# Brands_DARIGOLDRFG : 0.0
# Brands_DAROSARIO : 0.0
# Brands_DARTAGNANRFG : 0.0
# Brands_DELAMEREDAIRY : 0.0
# Brands_DELITIARFG : 0.0
# Brands_DELLAHRFG : 0.0
# Brands_DEMILL : 0.0
# Brands_DEWFRESH : 0.0
# Brands_DIMOCKDAIRY : 0.0
# Brands_DINNERBELL : 0.0
# Brands_DOBRERFG : 0.0
# Brands_DOWNEYSRFG : 0.0
# Brands_DUCHESSRFG : 0.0
# Brands_DUTCHFARMS : 0.0
# Brands_EARTHBALANCE : -0.0
# Brands_EBERHARDSRFG : 0.0
# Brands_EDENRFG : 0.0
# Brands_ELLATINO : 0.0
# Brands_ELLE& : 0.0
# Brands_ELLSWORTHRFG : 0.0
# Brands_ENGLISHDOUBLE : 0.0
# Brands_EPICUREANRFG : 0.0
# Brands_FABRIQUEDELICES : 0.0
# Brands_FALFURRIASRFG : -0.0
# Brands_FARMBESTRFG : 0.0
# Brands_FARMHOUSEKITCHENS : 0.0
# Brands_FARMSCREAMERY : 0.0
# Brands_FERMARFG : 0.0
# Brands_FERRARINIRFG : 0.0
# Brands_FINLANDIARFG : -0.0
# Brands_FIRSTPRIZE : 0.0
# Brands_FLEISCHMANNSRFG : -0.0
# Brands_FLORARFG : 0.0
# Brands_FLOWERBRAND : 0.0
# Brands_FONDO : 0.0
# Brands_FORAGERPROJECT : 0.0
# Brands_FOURSEASONS : 0.0
# Brands_FRENTELBUTTER : 0.0
# Brands_FRESHCHURNED : 0.0
# Brands_FRESHMADE : 0.0
# Brands_GEVINAFARMS : 0.0
# Brands_GLAVMASLOPROMRFG : 0.0
# Brands_GLENSTALFOODS : 0.0
# Brands_GLENVIEWFARMS : 0.0
# Brands_GOLDENDELICIOUS : 0.0
# Brands_GOLDENGOODNESS : 0.0
# Brands_GOLDENRAY : 0.0
# Brands_GOLDENWEST : 0.0
# Brands_GOLDN : 0.0
# Brands_GOYARFG : 0.0
# Brands_GRANDCRU : 0.0
# Brands_GRANDMAALICES : 0.0
# Brands_GRASSLANDRFG : 0.0
# Brands_GREENFIELDSRFG : 0.0
# Brands_GREENVALLEY : 0.0
# Brands_GUERNSEYRFG : 0.0
# Brands_GUIDASRFG : 0.0
# Brands_HANSENSFARM : 0.0
# Brands_HAOLAMRFG : 0.0
# Brands_HAPPYBOY : 0.0
# Brands_HARTZLERRFG : 0.0
# Brands_HEATHRILES : -0.0
# Brands_HERITAGEFAMILY : 0.0
# Brands_HIGHLAWN : 0.0
# Brands_HILANDRFG : 0.0
# Brands_HILDEBRANDRFG : 0.0
# Brands_HILLANDALEFARMS : 0.0
# Brands_HOGANSRFG : 0.0
# Brands_HOMEDAIRIES : 0.0
# Brands_HOMESTEADCREAMERY : 0.0
# Brands_HOPECREAMERY : 0.0
# Brands_HORIZONRFG : -0.0
# Brands_HOTELBAR : 0.0
# Brands_HOULTONFARMS : 0.0
# Brands_HUMBOLDTCREAMERY : 0.0
# Brands_HUMPTYDUMPTY : 0.0
# Brands_ICANT : -0.0
# Brands_IDAHOPREFERRED : 0.0
# Brands_IMPERIALRFG : 12750.908032625886
# Brands_INDIANLIFERFG : 0.0
# Brands_ISIGNYSTE : 0.0
# Brands_ISOLARFG : 0.0
# Brands_J& : 0.0
# Brands_JABBAFINE : 0.0
# Brands_JAMESFARM : 0.0
# Brands_JANSALVALLEY : 0.0
# Brands_JILBERTRFG : 0.0
# Brands_JOHNF : 0.0
# Brands_KALONASUPER : 0.0
# Brands_KALYPSORFG : 0.0
# Brands_KAROUNRFG : 0.0
# Brands_KASIARFG : 0.0
# Brands_KATESRFG : 0.0
# Brands_KELAPORFG : 0.0
# Brands_KELLERSRFG : 0.0
# Brands_KEMPSRFG : 0.0
# Brands_KERRYGOLDRFG : -0.0
# Brands_KERTSMANSRFG : 0.0
# Brands_KIMBALLBROOK : 0.0
# Brands_KITEHILL : -0.0
# Brands_KLEINPETERRFG : 0.0
# Brands_KOWALSKIRFG : 0.0
# Brands_KREMLINRFG : 0.0
# Brands_KRIEMHILDDAIRY : 0.0
# Brands_KROWKARFG : 0.0
# Brands_LAKESIDESTERRACE : 0.0
# Brands_LALARFG : 0.0
# Brands_LANDO : -0.0
# Brands_LARCHWOODFARMS : 0.0
# Brands_LATTERIASORESINA : 0.0
# Brands_LAVAQUITA : -0.0
# Brands_LAXMIRFG : 0.0
# Brands_LEHIGHVALLEY : 0.0
# Brands_LESCURERFG : 0.0
# Brands_LESPRES : 0.0
# Brands_LEWISROAD : 0.0
# Brands_LIBERTYBELL : 0.0
# Brands_LILYCHALONER : 0.0
# Brands_LOCALSOURCE : 0.0
# Brands_LOWELLRFG : 0.0
# Brands_LUDWIGDAIRY : 0.0
# Brands_LURPAKRFG : 0.0
# Brands_MAGNOLIARFG : 0.0
# Brands_MAISONF : 0.0
# Brands_MALCZEWSKIRFG : 0.0
# Brands_MASMIXRFG : 0.0
# Brands_MAVESARFG : 0.0
# Brands_MEADOWGOLD : 0.0
# Brands_MEDLEERFG : 0.0
# Brands_MEGGLERFG : 0.0
# Brands_MEHADRINRFG : 0.0
# Brands_MELTRFG : 0.0
# Brands_MEYENBERGRFG : 0.0
# Brands_MIDAMERICA : 0.0
# Brands_MIGDALRFG : 0.0
# Brands_MILKADAMIARFG : 0.0
# Brands_MILLEVERVILLECO : 0.0
# Brands_MINERVARFG : 0.0
# Brands_MIYOKOSCREAMERY : -0.0
# Brands_MLEKOVITARFG : 0.0
# Brands_MODELDAIRY : 0.0
# Brands_MOINEARRFG : 0.0
# Brands_MONTYSRFG : 0.0
# Brands_MOOSEMAPLE : 0.0
# Brands_MOOVILLERFG : 0.0
# Brands_MORNINGGLORY : 0.0
# Brands_MOTHERSCHOICE : 0.0
# Brands_MOTHERSRFG : 0.0
# Brands_MOUNTAINVIEW : 0.0
# Brands_MOVEOVER : -0.0
# Brands_NANAKMAKHANI : 0.0
# Brands_NANAKRFG : 0.0
# Brands_NAPOLEONRFG : 0.0
# Brands_NATURENATES : 0.0
# Brands_NELLIESRFG : -0.0
# Brands_NEUTRALRFG : 0.0
# Brands_NOBRANDMATHOT : 0.0
# Brands_NOBRANDPRIVATE : 0.0
# Brands_NOBRANDRFG : 0.0
# Brands_NOELSRFG : 0.0
# Brands_NORDICCREAMERY : 0.0
# Brands_NUCOARFG : -0.0
# Brands_NUTSFOR : 0.0
# Brands_OAKFARMS : 0.0
# Brands_OAKHURSTRFG : 0.0
# Brands_OBERWEISRFG : 0.0
# Brands_OLDWORLD : 0.0
# Brands_OLIVIORFG : -0.0
# Brands_OLSONSRFG : 0.0
# Brands_ORGANICPASTURES : 0.0
# Brands_ORGANICVALLEY : -0.0
# Brands_PARKAYRFG : -0.0
# Brands_PAYSANBRETON : 0.0
# Brands_PLEASANTACRES : 0.0
# Brands_PLUGRARFG : -0.0
# Brands_POLSKISMAK : 0.0
# Brands_PRAIRIEFARMS : 0.0
# Brands_PRESIDENTRFG : -0.0
# Brands_PRIVATELABEL : 2719.554981409881
# Brands_PRIZEOF : 0.0
# Brands_PRODUCERSDAIRY : 0.0
# Brands_PROMISERFG : -0.0
# Brands_PROPERFOOD : 0.0
# Brands_PULASKIRFG : 0.0
# Brands_PUREBLENDS : -0.0
# Brands_PURITYRFG : 0.0
# Brands_RAMARFG : 0.0
# Brands_RHODYFRESH : 0.0
# Brands_ROCKVIEWFAMILY : 0.0
# Brands_ROKISKIORFG : 0.0
# Brands_ROLMLECZRFG : 0.0
# Brands_RONNYBROOKRFG : 0.0
# Brands_ROYALCREST : 0.0
# Brands_RUMIANORFG : 0.0
# Brands_SABATINORFG : 0.0
# Brands_SAFFOLARFG : 0.0
# Brands_SALADSOF : 0.0
# Brands_SANTAMONICA : 0.0
# Brands_SCHROEDERRFG : 0.0
# Brands_SEAGOLD : 0.0
# Brands_SEATTLEBAGEL : 0.0
# Brands_SHAMROCKRFG : 0.0
# Brands_SHATTORFG : 0.0
# Brands_SHEDDSCOUNTRY : 0.0
# Brands_SHULLSBURGRFG : 0.0
# Brands_SIERRANEVADA : 0.0
# Brands_SIMPLYGHEE : 0.0
# Brands_SIMPLYPARKERS : 0.0
# Brands_SKANDINAVIYARFG : 0.0
# Brands_SLATEROOF : 0.0
# Brands_SLENDERCOW : 0.0
# Brands_SMAKOWITARFG : 0.0
# Brands_SMARTBALANCE : -261.2598980688145
# Brands_SMARTBEAT : 0.0
# Brands_SOMERDALERFG : 0.0
# Brands_SOMMERMAID : 0.0
# Brands_SORELLARFG : 0.0
# Brands_SOUTHERNSECRET : -0.0
# Brands_SPARKMANSCREAM : 0.0
# Brands_SPOMLEKRFG : 0.0
# Brands_SPOONBLOSSOMS : 0.0
# Brands_SPRINGHILL : 0.0
# Brands_STATEBRAND : 0.0
# Brands_STHELENS : 0.0
# Brands_STONYCREEK : 0.0
# Brands_STRAUSRFG : 0.0
# Brands_SUMNERSRFG : 0.0
# Brands_SUNHARVEST : 0.0
# Brands_SUNNYLANDRFG : 0.0
# Brands_SUNNYMORNING : 0.0
# Brands_SVALIARFG : 0.0
# Brands_SWISSVALLEY : 0.0
# Brands_TAAZARFG : 0.0
# Brands_TABLEMAID : 0.0
# Brands_TACIATERFG : 0.0
# Brands_TASTESLIKE : 0.0
# Brands_TERROIRSD : 0.0
# Brands_THURSDAYCOTTAGE : 0.0
# Brands_TILLAMOOKRFG : -0.0
# Brands_TINSTAR : 0.0
# Brands_TIPPERARYRFG : 0.0
# Brands_TNUVARFG : 0.0
# Brands_TONYSORIGINAL : 0.0
# Brands_TONYSRFG : 0.0
# Brands_TOPO : 0.0
# Brands_TREASUREFOODS : 0.0
# Brands_TRICKLINGSPRINGS : 0.0
# Brands_TROYERRFG : 0.0
# Brands_TRULYGRASS : 0.0
# Brands_TURNERSRFG : 0.0
# Brands_UMPQUARFG : 0.0
# Brands_UPSTATEFARMS : 0.0
# Brands_URBANIRFG : 0.0
# Brands_URBANTRUFFLES : 0.0
# Brands_VALEWOOD : 0.0
# Brands_VALLEYSHEPHERD : 0.0
# Brands_VELVETBEES : 0.0
# Brands_VERMONTRFG : -0.0
# Brands_VERNSRFG : 0.0
# Brands_VIOLIFERFG : -0.0
# Brands_VITALFARMS : -0.0
# Brands_WALNUTCREEK : 0.0
# Brands_WATERFORDIRISH : 0.0
# Brands_WAYFARERFG : 0.0
# Brands_WESTBYRFG : 0.0
# Brands_WESTFIELDFARMS : 0.0
# Brands_WESTGOLDRFG : -0.0
# Brands_WEYAUWEGARFG : 0.0
# Brands_WHOLESOMEFARMS : 0.0
# Brands_WILDBRINERFG : 0.0
# Brands_WILDCREAMERY : 0.0
# Brands_WILDHARVEST : 0.0
# Brands_WUTHRICHRFG : 0.0
# Brands_YUMMYRFG : 0.0
# Brands_ZEALGRASS : 0.0
# Brands_ZOYERFG : 0.0
# Brands_ZVIJEZDARFG : 0.0
# Year_2018 : -89.1815636629057
# Year_2019 : -0.0
# Year_2020 : 0.0
# Year_2021 : 0.0
# Year_2022 : 0.0
# Year_2023 : -0.0

# %%
lasso_coef
# Out:
#                                                Feature  Coefficient
# 0                              Price per Unit No Merch    -0.000000
# 1                             Price per Unit Any Merch  -483.681246
# 2                   ACV Weighted Distribution No Merch   615.760113
# 3                  ACV Weighted Distribution Any Merch   178.907598
# 4    Geography_California - IRI Standard - Multi Ou...  -142.710081
# ..                                                 ...          ...
# 385                                          Year_2019    -0.000000
# 386                                          Year_2020     0.000000
# 387                                          Year_2021     0.000000
# 388                                          Year_2022     0.000000
# 389                                          Year_2023    -0.000000
#
# [390 rows x 2 columns]

# %%
sns.regplot(x=y_testlasso,y=y_pred_lasso,ci=None,scatter_kws={"color": "green"}, line_kws={"color": "red"});
plt.title("Lasso model")
plt.xlabel("Unit Sales No Merch (Actual Value)")
plt.ylabel("Unit Sales No Merch (Predicted Value)")
# Out:
# Text(0, 0.5, 'Unit Sales No Merch (Predicted Value)')

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import precision_score, recall_score, mean_squared_error

# %%
var = ['Price per Unit No Merch', 'Price per Unit Any Merch','ACV Weighted Distribution No Merch','ACV Weighted Distribution Any Merch','Base Volume Sales','Brands_BLUEBONNET','Brands_PRIVATELABEL','Brands_SMARTBALANCE', 'Brands_IMPERIALRFG','Year_2018', 'Year_2019', 'Year_2020', 'Year_2021', 'Year_2022', 'Year_2023']
xpoly= pd.DataFrame(df_dummy[var])
ypoly= pd.DataFrame(df_dummy['Unit Sales No Merch'])

# %%
x_trainpoly, x_testpoly, y_trainpoly, y_testpoly = train_test_split(xpoly,ypoly,test_size= 0.2,random_state=5)

# %%
poly = make_pipeline(PolynomialFeatures(), LinearRegression())
param = {'polynomialfeatures__degree': [2]}
grid_poly = GridSearchCV(poly, param, cv = 5)
grid_poly.fit(x_trainpoly, y_trainpoly)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('polynomialfeatures',
#                                         PolynomialFeatures()),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              param_grid={'polynomialfeatures__degree': [2]})

# %%
grid_poly.best_params_
# Out:
# {'polynomialfeatures__degree': 2}

# %%
best_polymodel = grid_poly.best_estimator_

# %%
print("Coefficients = ", best_polymodel.named_steps['linearregression'].coef_)
print("\n \n Intercept = ",best_polymodel.named_steps['linearregression'].intercept_)
# Out:
# Coefficients =  [[ 6.41277199e-05  2.37258917e+01  9.19387886e+01  1.85636682e+02
#   -2.87035848e+02  3.26362375e-01  6.36116863e+03 -3.51086334e+01
#    1.31552387e+02  6.84182610e+03 -8.58759193e+00 -4.92963834e+01
#    1.64743218e+01  2.21783369e+01  3.70752813e+01 -1.78446549e+01
#   -3.47179647e-01  8.01331695e+00 -2.09290238e+01  3.27781835e+01
#   -4.38087516e-03 -4.46949856e+03 -8.29446957e+01 -8.25808273e+01
#   -9.46820108e+03 -1.06326234e+00  6.24228144e+00  1.02156956e+01
#    2.07552643e+01 -2.46590689e+01  1.23851340e+01 -6.40788329e-01
#   -1.01755237e+01  3.91004259e+01 -5.94003428e-02 -1.53648291e+03
#    4.59082905e+01  6.14776225e+01  1.70893698e+03  6.18513828e+01
#    9.96314373e+01 -4.46723093e+01 -5.40503114e+01  2.51839355e+01
#    3.99460376e+00  1.73547533e+00  2.47731177e+00  6.80170611e-03
#   -4.28002643e+02  1.90855700e+02 -1.10230518e+02 -5.88695211e+02
#    1.23980643e+01  1.95305825e+01  4.43958212e+01  2.34539922e+01
#    4.57513441e+01  4.01068761e+01  3.69029782e+00  1.23389983e-04
#   -3.38074402e+02 -1.26107240e+03 -2.45709959e+01 -5.41157983e+02
#   -6.91989089e+01 -9.27091411e+01 -5.18883789e+01  8.51507569e+01
#   -1.27566515e+02 -3.08234866e+01 -5.23126602e-07  3.09685467e-01
#    4.31375667e-01  1.35855429e-02  3.48820290e-01  2.08769627e-03
#   -1.82313987e-02  6.46403592e-02  6.02734328e-02  1.01288687e-01
#    1.15713303e-01  6.36116890e+03  0.00000000e+00 -2.27373675e-13
#    4.54747351e-13 -7.38240802e+02 -8.96319361e+02 -1.15174804e+03
#   -1.81478394e+03  3.75816209e+03  7.20409894e+03 -3.51090283e+01
#    4.54747351e-13  0.00000000e+00  2.91175338e+02  4.30489268e+02
#   -8.65097035e+01 -2.66800381e+02 -1.09214285e+02 -2.94249264e+02
#    1.31552178e+02  0.00000000e+00  3.31055717e+02  2.12501211e+02
#   -1.50269450e+02 -6.68071774e+02  3.88827871e+02  1.75086039e+01
#    6.84182643e+03  1.31893217e+03  2.58555721e+03 -1.84942117e+03
#   -1.68837723e+03  1.36585607e+03  5.10927938e+03 -8.58759546e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00 -4.92961938e+01  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.64740905e+01  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  2.21786026e+01  0.00000000e+00
#    0.00000000e+00  3.70755268e+01  0.00000000e+00 -1.78444307e+01]]
#
#
#  Intercept =  [-128.13006155]

# %%
y_poly_pred = best_polymodel.predict(x_testpoly)

# %%
print("R-Square  = {}".format(best_polymodel.score(x_testpoly,y_testpoly)))
# Out:
# R-Square  = 0.9124417161447806

# %%
print("MSE =",mean_squared_error(y_testpoly, y_poly_pred))
# Out:
# MSE = 23230490.71002036

# %%
sns.regplot(x=y_testpoly,y=y_poly_pred,ci=None,scatter_kws={"color": "green"}, line_kws={"color": "red"});
plt.title("Polynomial model")
plt.xlabel("Unit Sales No Merch (Actual Value)")
plt.ylabel("Unit Sales No Merch (Predicted Value)")
# Out:
# Text(0, 0.5, 'Unit Sales No Merch (Predicted Value)')

# %% [markdown]
# # Testing the model on 2019 Data

# %%
df2019_dummy = pd.get_dummies(df, columns=['Geography','Brands','Year'])

# %%
y_pred2019 = best_polymodel.predict(df2019_dummy[var])

# %%
y_test2019 = df2019_dummy['Unit Sales No Merch']

# %%
print("R-Square  = {}".format(best_polymodel.score(df2019_dummy[var],y_test2019)))
# Out:
# R-Square  = 0.9095075630579582

# %%
sns.regplot(x=y_test2019,y=y_pred2019,ci=None,scatter_kws={"color": "green"}, line_kws={"color": "red"});
plt.title("Polynomial Model Tested on 2019 Dataset")
plt.xlabel("Unit Sales No Merch (Actual Value)")
plt.ylabel("Unit Sales No Merch (Predicted Value)")
# Out:
# Text(0, 0.5, 'Unit Sales No Merch (Predicted Value)')
